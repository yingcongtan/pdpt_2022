# %%
import os, sys

src_dir_ = '/home/tan/Documents/GitHub/pdpt_2022/src'
sys.path.insert(1, src_dir_)

import numpy as np
import matplotlib.pyplot as plt
import time
from gurobipy import Model, quicksum, GRB

from pdotw_mip import group_cycle_truck, postprocess_solution_pdotw, eval_pdotw_sol
from util import generate_node_cargo_size_change

# %%
def optimize_pdotw_route_gurobi(constant, y_sol,
    selected_cargo, single_truck_deviation,
    created_truck_yCycle, created_truck_nCycle, created_truck_all,
    node_list_truck_hubs, selected_edge, node_cargo_size_change, 
    runtime, filename, verbose = 0):
    
    """
    This model is a modified version of the PDOTW model.

    Now, y_sol, the cargo to truck assignment is given, so the goal is to minimize the traveling distance.

    return 
    1. obj_val_MP: objective value
    2. runtime_MP: runtime
    3. x_sol, _, _ , S_sol, D_sol, A_sol, 
       Sb_sol, Db_sol, Ab_sol: values of variables
        
    """
    
    MP = Model("Gurobi MIP for reoptimizing PDOTW routes")
    

    # binary variables y
    # ==1 if cargo_ is carried by truck_
    y = {}
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            y[(truck_, cargo_)] = y_sol[(truck_, cargo_)]

    ###### Decision Variables ######
    ###### six types of decision variables ######
    
    # binary variables x
    # ==1 if the truck_ traverse an edge 
    x = {}
    for truck_ in created_truck_all.keys():
        for i in node_list_truck_hubs[truck_]:
            for j in node_list_truck_hubs[truck_]:
                if i != j:
                    x[(i, j, truck_)] = \
                    MP.addVar(vtype=GRB.BINARY)
    


    # Integer variables S
    # current total size of cargos on truck_ at node_
    S = {}
    Sb = {}
    for truck_ in created_truck_all.keys():
        for node_ in node_list_truck_hubs[truck_]:
            S[(node_, truck_)] = MP.addVar(vtype=GRB.INTEGER, lb=0,
                                           ub=created_truck_all[truck_][3])
    # if truck_ is a cycle truck and node_ is its destination
    # add a decision variable Sb
    # NOT A D VARIABLE ANYMORE
    for truck_ in created_truck_yCycle.keys():
        node_ = created_truck_yCycle[truck_][1]
        Sb[(node_, truck_)] = 0
    
    # integer variable D
    # departure time of truck_ at node_
    D = {}
    Db = {}
    for truck_ in created_truck_all.keys():
        for node_ in node_list_truck_hubs[truck_]:
            D[(node_, truck_)] = MP.addVar(vtype=GRB.INTEGER, lb=0)
    # if truck_ is a cycle truck and node_ is its destination
    # add a decision variable Ab
    for truck_ in created_truck_yCycle.keys():
        node_ = created_truck_yCycle[truck_][1]
        Db[(node_, truck_)] = MP.addVar(vtype=GRB.INTEGER, lb=0)
    
    # integer variable A
    # arrival time of truck_ at node_
    A = {}
    Ab = {}
    for truck_ in created_truck_all.keys():
        for node_ in node_list_truck_hubs[truck_]:
            A[(node_, truck_)] = MP.addVar(vtype=GRB.INTEGER, lb=0)
    # if truck_ is a cycle truck and node_ is its destination
    # add a decision variable Db
    for truck_ in created_truck_yCycle.keys():
        node_ = created_truck_yCycle[truck_][1]
        Ab[(node_, truck_)] = MP.addVar(vtype=GRB.INTEGER, lb=0)
    
    ###### Constraints ######
    ###### Distinguish cycle trucks and non-cycle trucks ######
    
    # Flow constraints (3.1)
    # the truck must start from its origin
    for truck_ in created_truck_all.keys():
        origin_truck = created_truck_all[truck_][0]
        if origin_truck in node_list_truck_hubs[truck_]:
            MP.addConstr( 
                quicksum(x[(origin_truck, succ_node, truck_)] * 1
                         for succ_node in node_list_truck_hubs[truck_]
                         if succ_node != origin_truck) == 1 
            )
        
    # Flow constraints (3.2)  
    # only applies to non-cycle trucks
    # no flow enters the origin of a non-cycle truck
    for truck_ in created_truck_nCycle.keys():
        origin_truck = created_truck_nCycle[truck_][0]
        if origin_truck in node_list_truck_hubs[truck_]:
            MP.addConstr( 
                quicksum(x[(succ_node, origin_truck, truck_)] * 1
                         for succ_node in node_list_truck_hubs[truck_]
                         if succ_node != origin_truck) == 0 
            )

    # Flow constraints (3.3)
    # the truck must end at its destination
    for truck_ in created_truck_all.keys():
        destination_truck = created_truck_all[truck_][1]
        if destination_truck in node_list_truck_hubs[truck_]:
            MP.addConstr( 
                quicksum(x[(pred_node, destination_truck, truck_)] * 1
                         for pred_node in node_list_truck_hubs[truck_]
                         if pred_node != destination_truck) == 1
            )    
        
    # Flow constraints (3.4)
    # only applies to non-cycle trucks
    # no flow departs from the destination of a non-cycle truck
    for truck_ in created_truck_nCycle.keys():
        destination_truck = created_truck_nCycle[truck_][1]
        if destination_truck in node_list_truck_hubs[truck_]:
            MP.addConstr( 
                quicksum(x[(destination_truck, pred_node, truck_)] * 1
                         for pred_node in node_list_truck_hubs[truck_]
                         if pred_node != destination_truck) == 0 
            )
    
    
    ### No cycle part below ----------------------------------------------
    
    # Flow constraints (3.5)
    # flow in = flow out
    # Don't consider origin_truck and destination_truck in this constraint
    for truck_ in created_truck_all.keys():
        origin_truck = created_truck_all[truck_][0]
        destination_truck = created_truck_all[truck_][1]
        for node_ in node_list_truck_hubs[truck_]:
            if node_ != origin_truck and node_ != destination_truck:
                MP.addConstr(
                    quicksum(x[(pred_node, node_, truck_)] * 1
                             for pred_node in node_list_truck_hubs[truck_]
                             if pred_node != node_) 
                    ==
                    quicksum(x[(node_, succ_node, truck_)] * 1
                             for succ_node in node_list_truck_hubs[truck_]
                             if succ_node != node_) 
                )
    
    # An edge is used at most once by a truck (3.6)
    # only apply for non-cycle trucks
    # and non-origin nodes for cycle trucks
    for truck_ in created_truck_nCycle.keys():
        for i in node_list_truck_hubs[truck_]:
            for j in node_list_truck_hubs[truck_]:
                if i != j:
                    MP.addConstr(
                        x[(i, j, truck_)] +
                        x[(j, i, truck_)]
                        <= 1
                    )
    for truck_ in created_truck_yCycle.keys():
        origin_truck = created_truck_yCycle[truck_][0]
        for i in node_list_truck_hubs[truck_]:
            for j in node_list_truck_hubs[truck_]:
                if i != j:
                    if i != origin_truck and j != origin_truck:
                        MP.addConstr(
                            x[(i, j, truck_)] +
                            x[(j, i, truck_)]
                            <= 1
                        )
            
    
    # origin_c is visited by truck_ if y[(truck_, c)] == 1 (3.9)
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            origin_cargo = selected_cargo[cargo_][3]
            if origin_cargo in node_list_truck_hubs[truck_]:
                MP.addConstr(
                    quicksum(x[(origin_cargo, node_, truck_)] * 1
                             for node_ in node_list_truck_hubs[truck_]
                             if node_ != origin_cargo)
                    >= 
                    y[(truck_, cargo_)]
                )
    
    # destination_c is visited by truck_ if y[(truck_, c)] == 1 (3.10)
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            destination_cargo = selected_cargo[cargo_][4]
            if destination_cargo in node_list_truck_hubs[truck_]:
                MP.addConstr(
                    quicksum(x[(node_, destination_cargo, truck_)] * 1
                             for node_ in node_list_truck_hubs[truck_]
                             if node_ != destination_cargo)
                    >= 
                    y[(truck_, cargo_)]
                )
    
    ### Capacity ----------------------------------------------------
    
    # capacity constraints (3.14)
    for truck_ in created_truck_all.keys():
        # if truck_ is a NON-cycle truck and node_ is its destination
        # then the truck capacity when departing its destination is 0
        if truck_ in created_truck_nCycle.keys():
            destination_truck = created_truck_all[truck_][1]
            MP.addConstr(
                S[(destination_truck, truck_)] 
                == 0
            )
            
    # Cumulative total size of a truck at a node (3.15)
    # be aware of whether the node is 
    # a cargo origin or cargo destination, or both
    bigM_capacity = 30000
    for truck_ in created_truck_all.keys():
        for node1 in node_list_truck_hubs[truck_]:
            for node2 in node_list_truck_hubs[truck_]:
                if node1 != node2:
                    # if truck_ is a cycle truck 
                    # and node2 is its destination
                    if truck_ in created_truck_yCycle.keys():
                        if node2 == created_truck_yCycle[truck_][1]:
                            MP.addConstr(
                                Sb[(node2, truck_)] - S[(node1, truck_)]
                                >= 
                                quicksum(y[(truck_, cargo_)] * 
                                node_cargo_size_change[(node2, cargo_)]
                                for cargo_ in selected_cargo.keys()
                                if selected_cargo[cargo_][4] == node2)
                                - bigM_capacity 
                                * (1 - x[(node1, node2, truck_)])
                            )
                        else:
                            MP.addConstr(
                                S[(node2, truck_)] - S[(node1, truck_)]
                                >= 
                                quicksum(y[(truck_, cargo_)] * 
                                node_cargo_size_change[(node2, cargo_)]
                                for cargo_ in selected_cargo.keys()
                                if selected_cargo[cargo_][4] == node2 \
                                or selected_cargo[cargo_][3] == node2)
                                - bigM_capacity 
                                * (1 - x[(node1, node2, truck_)])
                            )
                    # else
                    else:
                        if node2 == created_truck_nCycle[truck_][1]:
                            MP.addConstr(
                                S[(node2, truck_)] - S[(node1, truck_)]
                                >= 
                                quicksum(y[(truck_, cargo_)] * 
                                node_cargo_size_change[(node2, cargo_)]
                                for cargo_ in selected_cargo.keys()
                                if selected_cargo[cargo_][4] == node2)
                                - bigM_capacity 
                                * (1 - x[(node1, node2, truck_)])
                            )
                        else:
                            MP.addConstr(
                                S[(node2, truck_)] - S[(node1, truck_)]
                                >= 
                                quicksum(y[(truck_, cargo_)] * 
                                node_cargo_size_change[(node2, cargo_)]
                                for cargo_ in selected_cargo.keys()
                                if selected_cargo[cargo_][4] == node2 \
                                or selected_cargo[cargo_][3] == node2)
                                - bigM_capacity 
                                * (1 - x[(node1, node2, truck_)])
                            )
    # Change 20220911 TAN
    # Add total size of cargo <= M * sum_j x^k(i,j)
    for truck_ in created_truck_all.keys():
        for node1 in node_list_truck_hubs[truck_]:
            # if truck_ is a cycle truck 
            # and node2 is its destination
            MP.addConstr(
                S[(node1, truck_)]<= 
                bigM_capacity * quicksum(x[(node1, node2, truck_)]\
                        for node2 in node_list_truck_hubs[truck_] if node1 != node2))

    # total size of cargos at truck origins (3.16)  
    # Should be an equality constraint
    for truck_ in created_truck_all.keys():
        origin_truck = created_truck_all[truck_][0]
        MP.addConstr(
            S[(origin_truck, truck_)] == 
            quicksum(y[(truck_, cargo_)] * \
                     node_cargo_size_change[(origin_truck, cargo_)]
                     for cargo_ in selected_cargo.keys()
                     if selected_cargo[cargo_][3] == origin_truck)
        )
    
    ### Time --------------------------------------------------------
    # The arrival time of a truck at any node (even if not visited) 
    # is less than or equal to the departure time of a truck
    for truck_ in created_truck_all.keys():
        for node_ in node_list_truck_hubs[truck_]:
            if truck_ in created_truck_yCycle.keys() and \
               node_ == created_truck_yCycle[truck_][1]:
                MP.addConstr(
                    Ab[(node_, truck_)] 
                    <= Db[(node_, truck_)]
                )
                MP.addConstr(
                    A[(node_, truck_)] 
                    <= D[(node_, truck_)]
                )
            else:
                MP.addConstr(
                    A[(node_, truck_)] 
                    <= D[(node_, truck_)]
                )
    
    # loading and unloading time between arrival and departure (3.17)
    # Don't consider origin_truck in this constraint
    # but for cycle trucks, their origins are also their destinations
    # so we only consider their destination parts
    for truck_ in created_truck_all.keys():
        for node_ in node_list_truck_hubs[truck_]:
            # if truck_ is a cycle truck
            if truck_ in created_truck_yCycle.keys():
                # if node_ is its destination
                if node_ == created_truck_yCycle[truck_][1]:
                    MP.addConstr(
                        Ab[(node_, truck_)] +
                        constant['node_fixed_time'] +
                        quicksum(y[(truck_, cargo_)] * 
                                 int(np.ceil(selected_cargo[cargo_][0] * 
                                 constant['loading_variation_coefficient']))
                                 for cargo_ in selected_cargo.keys()
                                 if node_ == selected_cargo[cargo_][4])
                        <= Db[(node_, truck_)]
                    )
                else:
                    MP.addConstr(
                        A[(node_, truck_)] +
                        constant['node_fixed_time'] +
                        quicksum(y[(truck_, cargo_)] * 
                                 int(np.ceil(selected_cargo[cargo_][0] * 
                                 constant['loading_variation_coefficient']))
                                 for cargo_ in selected_cargo.keys()
                                 if node_ == selected_cargo[cargo_][3] \
                                 or node_ == selected_cargo[cargo_][4])
                        <= D[(node_, truck_)]
                    )
            # if truck_ is a non-cycle truck
            else:
                if node_ != created_truck_all[truck_][0]:
                    if node_ == created_truck_all[truck_][1]:
                        MP.addConstr(
                            A[(node_, truck_)] +
                            constant['node_fixed_time'] +
                            quicksum(y[(truck_, cargo_)] * 
                                     int(np.ceil(selected_cargo[cargo_][0] * 
                                     constant['loading_variation_coefficient']))
                                     for cargo_ in selected_cargo.keys()
                                     if node_ == selected_cargo[cargo_][4])
                            <= D[(node_, truck_)]
                        )
                    else:
                        MP.addConstr(
                            A[(node_, truck_)] +
                            constant['node_fixed_time'] +
                            quicksum(y[(truck_, cargo_)] * 
                                     int(np.ceil(selected_cargo[cargo_][0] * 
                                     constant['loading_variation_coefficient']))
                                     for cargo_ in selected_cargo.keys()
                                     if node_ == selected_cargo[cargo_][3] \
                                     or node_ == selected_cargo[cargo_][4])
                            <= D[(node_, truck_)]
                        )
    
    # bigM constraints for travel time on edge(i,j) (3.18) 
    # D[prev_node] + edge[(prev_node, curr_node)] <= A[curr_node]
    bigM_time = 2000
    for truck_ in created_truck_all.keys():
        for node1 in node_list_truck_hubs[truck_]:
            for node2 in node_list_truck_hubs[truck_]:
                if node1 != node2:
                    # if truck_ is a cycle truck and 
                    # node2 is its destination
                    if truck_ in created_truck_yCycle.keys() and \
                       node2 == created_truck_yCycle[truck_][1]:
                        MP.addConstr(
                            D[(node1, truck_)] +
                            selected_edge[(node1, node2)]
                            <= 
                            Ab[(node2, truck_)] +
                            bigM_time * (1 - x[(node1, node2, truck_)])
                        )
                    else:
                        MP.addConstr(
                            D[(node1, truck_)] +
                            selected_edge[(node1, node2)]
                            <= 
                            A[(node2, truck_)] +
                            bigM_time * (1 - x[(node1, node2, truck_)])
                        )
    
    # Earliest time window of cargos (3.19)
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            origin_cargo = selected_cargo[cargo_][3]
            if origin_cargo in node_list_truck_hubs[truck_]:
                MP.addConstr(
                    D[(origin_cargo, truck_)]
                    >= 
                    selected_cargo[cargo_][1] * y[(truck_, cargo_)]
                )
            
    # Latest time window of cargos (3.20)
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            destination_cargo = selected_cargo[cargo_][4]
            if destination_cargo in node_list_truck_hubs[truck_]:
                # if truck_ is a cycle truck and 
                # destination_cargo is its destination
                if truck_ in created_truck_yCycle.keys() and \
                   destination_cargo == created_truck_yCycle[truck_][1]:
                    MP.addConstr(
                        Ab[(destination_cargo, truck_)]
                        <= 
                        selected_cargo[cargo_][2] + 
                        bigM_time * (1 - y[(truck_, cargo_)])
                    )
                else:
                    MP.addConstr(
                        A[(destination_cargo, truck_)]
                        <= 
                        selected_cargo[cargo_][2] + 
                        bigM_time * (1 - y[(truck_, cargo_)])
                    )

    # maximum worktime of trucks (3.21)
    for truck_ in created_truck_all.keys():
        origin_truck = created_truck_all[truck_][0]
        destination_truck = created_truck_all[truck_][1]
        # if truck_ is a cycle truck
        if truck_ in created_truck_yCycle.keys():
            MP.addConstr(
                Db[(destination_truck, truck_)] - D[(origin_truck, truck_)]
                <= 
                created_truck_yCycle[truck_][2]  # z[truck_] * 
            )
            MP.addConstr(
                Db[(destination_truck, truck_)] - D[(origin_truck, truck_)]
                >= 
                0  # z[truck_] * 
            )
        else:
            MP.addConstr(
                D[(destination_truck, truck_)] - D[(origin_truck, truck_)]
                <= 
                created_truck_all[truck_][2]  # z[truck_] * 
            )
            MP.addConstr(
                D[(destination_truck, truck_)] - D[(origin_truck, truck_)]
                >= 
                0  # z[truck_] * 
            )

    
    # first pickup and then delivery (3.22)
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            origin_cargo = selected_cargo[cargo_][3]
            destination_cargo = selected_cargo[cargo_][4]
            if destination_cargo in node_list_truck_hubs[truck_]:
                # if truck_ is a cycle truck and 
                # destination_cargo is its destination
                if truck_ in created_truck_yCycle.keys() and \
                   destination_cargo == created_truck_yCycle[truck_][1]:
                    MP.addConstr(
                        Ab[(destination_cargo, truck_)] - 
                        D[(origin_cargo, truck_)]
                        >= 
                        selected_edge[(origin_cargo, destination_cargo)] -
                        bigM_time * (1 - y[(truck_, cargo_)])
                    )
                    MP.addConstr(
                        A[(origin_cargo, truck_)] - 
                        D[(destination_cargo, truck_)]
                        >= 
                        selected_edge[(destination_cargo, origin_cargo)] -
                        bigM_time * (1 - y[(truck_, cargo_)])
                    )
                else:
                    MP.addConstr(
                        A[(destination_cargo, truck_)] - 
                        D[(origin_cargo, truck_)]
                        >= 
                        selected_edge[(origin_cargo, destination_cargo)] -
                        bigM_time * (1 - y[(truck_, cargo_)])
                    )
            
            
            
            
    
    ###### Objective ######
    
    # # traveling cost: proportional to total travel time
    cost_travel = quicksum(x[(node1, node2, truck_)] * 
                           selected_edge[(node1, node2)] * 
                           constant['truck_running_cost']
                           for truck_ in created_truck_all.keys()
                           for node1 in node_list_truck_hubs[truck_]
                           for node2 in node_list_truck_hubs[truck_]
                           if node1 != node2)

    # private parameters to help with callback function
    MP._cur_obj = float('inf')
    MP._time = time.time()
    MP._no_improve_iter = 0
    MP._termination_flag = 0

    MP.setObjective(cost_travel)
    MP.modelSense = GRB.MINIMIZE
    MP.Params.timeLimit = runtime
    MP.Params.OutputFlag = 1
    MP.Params.LogFile = filename
    MP.Params.LogToConsole  = 0
    MP.update()
    MP.optimize()


    # if infeasible
    if MP.Status == 3:
        if verbose >0: print('+++ MIP [Infeasible Proved] ')
        return -1, runtime, [], [], [], [], [], [], [], [], [], -1, -1, -1, -1
    
    runtime_MP = MP.Runtime
    obj_val_MP = MP.objVal

    
    # if no objective value
    if float('inf') == obj_val_MP:
        if verbose >0: print('+++ MIP [Infeasible] ')
        return -1, runtime, [], [], [], [], [], [], [], [], [], -1, -1, -1, -1
        
    
    if verbose > 0:
        print('+++ MP [Feasible] ')
        if MP._termination_flag == 1:
            print('soft termination: failed to improve best solution for 20s.')
        elif MP._termination_flag == 2:
            print('soft termination: failed to improve obj for 50 consecutive feasible solutions.')
        print("   [Gurobi obj value] is %i" % obj_val_MP)
        print("   [Gurobi runtime] is %f" % runtime_MP)
    
    
    
    ###### Get solutions ######
    
    # store all values in a list: sol
    sol = []
    for ss in MP.getVars():
        sol.append(int(ss.x))
        
    # retrieve values from the list sol
    count = 0
    # binary variables x
    x_sol = {}
    for truck_ in created_truck_all.keys():
        for i in node_list_truck_hubs[truck_]:
            for j in node_list_truck_hubs[truck_]:
                if i != j:
                    x_sol[(i, j, truck_)] = sol[count]
                    count += 1
                
    # # binary variables y
    # y_sol = {}
    # for truck_ in created_truck_all.keys():
    #     for cargo_ in selected_cargo.keys():
    #         y_sol[(truck_, cargo_)] = sol[count]
    #         count += 1
    
    # integer variable S
    S_sol = {}
    Sb_sol = {}
    for truck_ in created_truck_all.keys():
        for node_ in node_list_truck_hubs[truck_]:
            S_sol[(node_, truck_)] = sol[count]
            count += 1
    # if truck_ is a cycle truck and node_ is its destination
    for truck_ in created_truck_yCycle.keys():
        node_ = created_truck_yCycle[truck_][1]
        Sb_sol[(node_, truck_)] = 0
            
    # integer variable D
    D_sol = {}
    Db_sol = {}
    for truck_ in created_truck_all.keys():
        for node_ in node_list_truck_hubs[truck_]:
            D_sol[(node_, truck_)] = sol[count]
            count += 1
    # if truck_ is a cycle truck and node_ is its destination
    for truck_ in created_truck_yCycle.keys():
        node_ = created_truck_yCycle[truck_][1]
        Db_sol[(node_, truck_)] = sol[count]
        count += 1
    
    # integer variable A
    A_sol = {}
    Ab_sol = {}
    for truck_ in created_truck_all.keys():
        for node_ in node_list_truck_hubs[truck_]:
            A_sol[(node_, truck_)] = sol[count]
            count += 1
    # if truck_ is a cycle truck and node_ is its destination
    for truck_ in created_truck_yCycle.keys():
        node_ = created_truck_yCycle[truck_][1]
        Ab_sol[(node_, truck_)] = sol[count]
        count += 1
    
    if verbose > 1:
        print('+++ The x_sol:')
        for key, value in x_sol.items():
            if value == 1:
                print(f'        {key, value}')
        print('+++ The y_sol:')
        for key, value in y_sol.items():
            if value == 1:
                print(f'        {key, value}')

    # cargo cost: proportional to the total size of cargo carried by the only truck
    cost_cargo_size_value = 0
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            cost_cargo_size_value += \
            y_sol[truck_, cargo_] * selected_cargo[cargo_][0] * \
            constant['truck_running_cost'] * 1
    if verbose >1:
        print('+++ [cost_cargo_size_value] ', cost_cargo_size_value)
    
    # cargo number cost: proportional to the number of cargo carried by the only truck
    cost_cargo_number_value = 0
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            cost_cargo_number_value += \
            y_sol[truck_, cargo_] * constant['truck_running_cost'] * 1000
    if verbose >1:
        print('+++ [cost_cargo_number_value] ', cost_cargo_number_value)
    
    # traveling cost: proportional to total travel time
    cost_travel_value = 0
    for truck_ in created_truck_all.keys():
        for node1 in node_list_truck_hubs[truck_]:
            for node2 in node_list_truck_hubs[truck_]:
                if node1 != node2:
                    cost_travel_value += x_sol[(node1, node2, truck_)] * \
                    selected_edge[(node1, node2)] * \
                    constant['truck_running_cost']
    if verbose >1:
        print('+++ [cost_travel_value] ', cost_travel_value)
    
    # deviation cost: proportional to total deviation of cargo carried by the only truck
    cost_deviation_value = 0
    for truck_ in created_truck_all.keys():
        for cargo_ in selected_cargo.keys():
            cost_deviation_value += \
            y_sol[truck_, cargo_] * 1 * \
            single_truck_deviation[(cargo_, truck_)] * \
            constant['truck_running_cost']
    if verbose >1:
        print('+++ [cost_deviation_value] ', cost_deviation_value, '\n')
    
    
         
    del MP

    
    return obj_val_MP, runtime_MP, \
           x_sol, {}, {}, S_sol, D_sol, A_sol, \
           Sb_sol, Db_sol, Ab_sol, \
           cost_cargo_size_value, cost_cargo_number_value, \
           cost_travel_value, cost_deviation_value

# %%
from pandas import read_pickle

def optimize_pdotw_mip(ins,  # dict contains the data of pdpt instance,
                        path_, # file where all data of pdotw solutions are saved
                        verbose = 0):  





    # load data from ins
    truck_list = ins['truck']
    cargo_list = ins['cargo']
    selected_cargo = cargo_list.copy()

    # edges = ins['edges']
    # nodes = ins['nodes']
    constant = ins['constant']
    node_cargo_size_change = ins['node_cargo_size_change']
    edge_shortest = ins['edge_shortest']
    # path_shortest = ins['path_shortest']
    single_truck_deviation = ins['single_truck_deviation']

    # pdotw_sol = read_pickle(os.path.join(path_, 'toy_initSol.pkl'))
    # pdotw_sol = read_pickle(os.path.join(path_, 'toy_initSol.pkl'))
    pdotw_sol = read_pickle(path_+'_initSol.pkl')


    # res = {'MIP': {'x_sol': x_sol_total,
    #                'y_sol': y_sol_total,
    #                'S_sol': S_sol_total,
    #                'D_sol': D_sol_total,
    #                'A_sol': A_sol_total,
    #                'Sb_sol': Sb_sol_total,
    #                'Db_sol': Db_sol_total,
    #                'Ab_sol': Ab_sol_total,
    #                'runtime': runtime_pdotw,
    #               },
    #        'route': {'truck_yCycle':list(created_truck_yCycle_total.keys()),
    #                  'used_truck': truck_used_total,
    #                  'truck_route': truck_route,
    #                  'cargo_route': cargo_route,
    #                 },
    #        'cost': {'truck_cost' : truck_cost,
    #                 'travel_cost' : travel_cost,
    #                 },
    #       }


    y_sol = pdotw_sol['MIP']['y_sol']
    truck_route_sol = pdotw_sol['route']['truck_route']
    cargo_route_sol = pdotw_sol['route']['cargo_route']
    used_truck = pdotw_sol['route']['used_truck']

    carog_truck_assignment = {}

    truck_used_total = []
    truck_route = {}
    for t_key, t_value in truck_list.items():
        truck_route[t_key] = []
        truck_route[t_key].append(t_value[0])

    cargo_delivered_total = {} 
    cargo_undelivered_total = {} 
    cargo_route = {}
    truck_per_cargo = {}
    for c_key, _ in cargo_list.items():
        truck_per_cargo[c_key] = -1
        cargo_route[c_key] = []
    cargo_in_truck = {}

    for truck_key in used_truck:
        print(f' +++ START re-optimize PDOTW solution for  truck [{truck_key}] \n')
        carog_truck_assignment[truck_key] = [key[1] for key in y_sol.keys() if (key[0]==truck_key and y_sol[key]==1)]
        print(f' +++ Truck [{truck_key}]: [{truck_route_sol[truck_key]}]')
        print(f' +++ Cargos to deliver: [{carog_truck_assignment[truck_key]}]')

        tv = truck_list[truck_key]
        created_truck = {}
        created_truck[truck_key] = tv

        node_list_truck_hubs = {}
        delivered_cargo = {cargo_key: cargo_list[cargo_key] for cargo_key in carog_truck_assignment[truck_key]}
        
        # nodes in the cluster
        # Note. cargo['nb_cargo'] = ['size', 'lb_time', 'ub_time','departure_node', 'arrival_node']
        # truck['nb_truck'] = ['departure_node', 'arrival_node', 'max_worktime', 'max_capacity']

        selected_node = []
        for v in delivered_cargo.values():
            if v[3] not in selected_node:
                selected_node.append(v[3])
            if v[4] not in selected_node:
                selected_node.append(v[4])
        if tv[0] not in selected_node:
            selected_node.append(tv[0])
        if tv[1] not in selected_node:
            selected_node.append(tv[1])

    # edges in the cluster
        selected_edge = {}
        for i in selected_node:
            for j in selected_node:
                selected_edge[(i,j)] = edge_shortest[(i,j)]
        
        node_list_truck_hubs[truck_key] = selected_node.copy()
        assert len(created_truck) == len(node_list_truck_hubs), "Inconsistent truck numbers"
        node_cargo_size_change = \
        generate_node_cargo_size_change(selected_node, delivered_cargo)

        ### group cycle and non-cycle trucks
        created_truck_yCycle, created_truck_nCycle, created_truck_all = \
        group_cycle_truck(created_truck) 


        # gurobi_log_file = os.path.join(path_, f'toy_gurobi/truck{truck_key}_reoptimized.log')
        gurobi_log_file = path_+f'_gurobi/truck{truck_key}_reoptimized.log'

        obj_val_MP, runtime_MP, \
        x_sol, _, _, S_sol, D_sol, A_sol, \
        Sb_sol, Db_sol, Ab_sol, \
        cost_cargo_size_value, cost_cargo_number_value, \
        cost_travel_value, cost_deviation_value\
        = optimize_pdotw_route_gurobi(constant, y_sol,
        delivered_cargo, single_truck_deviation,
        created_truck_yCycle, created_truck_nCycle, created_truck_all,
        node_list_truck_hubs, selected_edge, node_cargo_size_change,
        100, gurobi_log_file, verbose = 1)

        x_sol_total, y_sol_total, S_sol_total,\
        D_sol_total, A_sol_total, Sb_sol_total,\
        Db_sol_total, Ab_sol_total = {}, {}, {}, {}, {}, {}, {}, {}

        if obj_val_MP >= 0:
            if verbose >0:
                print(f'+++ Postprocee Gurobi solution if a feasible solution is found')

            for key, value in x_sol.items():
                x_sol_total[key] = value
            for key, value in y_sol.items():
                y_sol_total[key] = value
            for key, value in S_sol.items():
                S_sol_total[key] = value
            for key, value in D_sol.items():
                D_sol_total[key] = value
            for key, value in A_sol.items():
                A_sol_total[key] = value
            for key, value in Sb_sol.items():
                Sb_sol_total[key] = value
            for key, value in Db_sol.items():
                Db_sol_total[key] = value
            for key, value in Ab_sol.items():
                Ab_sol_total[key] = value

            ### post-process the solution
            truck_used, cargo_delivered, cargo_undelivered, \
            cargo_truck_total, cargo_in_truck = \
            postprocess_solution_pdotw(cargo_list, truck_list, 
            delivered_cargo, created_truck_all,
            node_list_truck_hubs, 
            x_sol, y_sol, truck_route, cargo_route, verbose = verbose-1)

            print(f' +++ New route {truck_route[truck_key]}')

            for truck_ in truck_used:
                if truck_ not in truck_used_total:
                    truck_used_total.append(truck_)

            for c_key, c_value in cargo_delivered.items():
                cargo_delivered_total[c_key] = c_value

            for c_key, c_value in cargo_undelivered.items():
                cargo_undelivered_total[c_key] = c_value

            for c_key, c_value in cargo_truck_total.items():
                if v != -1:
                    truck_per_cargo[c_key] = c_value
            for t_key, t_value in cargo_in_truck.items():
                cargo_in_truck[t_key] = t_value.copy()

        print(f' +++ END re-optimize PDOTW solution for  truck [{truck_key}] \n')

    truck_cost, travel_cost = eval_pdotw_sol(constant, edge_shortest, truck_used_total, truck_route)
    old_cost = pdotw_sol['cost']['travel_cost']
    print(f' +++ old travel cost: [{old_cost}]')
    print(f' +++ new travel cost: [{travel_cost}]')

# %%
toy_path_ =  '/home/tan/Documents/GitHub/pdpt_2022/toy/'
fujitsu_path_ =  '/home/tan/Documents/GitHub/pdpt_2022/'

# pdpt_ins = read_pickle(os.path.join(path_, 'toy.pkl'))

# case_num=1

for case_num in range(1,6,1):
    print(f'====== Re-optimize PDOTW solutions for Case {case_num}')
    pdpt_ins = read_pickle(os.path.join(fujitsu_path_, 'data', f'case{case_num}.pkl'))
    path_ = fujitsu_path_ + f'out/case{case_num}'
    optimize_pdotw_mip(pdpt_ins, path_)
# Out:
# ====== Re-optimize PDOTW solutions for Case 1
# ========= Reoptimize the route of PDOTW sol on Truck [T11]
#  +++ Truck [T11]: [['N10', 'N19', 'N21', 'N14']]
#  +++ Cargos to deliver: [['C9', 'C11', 'C12', 'C20', 'C29', 'C30', 'C31', 'C32', 'C88', 'C120', 'C139', 'C140', 'C145', 'C147', 'C152', 'C156', 'C170', 'C222', 'C232', 'C235']]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-09
]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case1_gurobi/truckT5_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 22550
#    [Gurobi runtime] is 0.000996
#  +++ New route ['N5', 'N10', 'N27', 'N22', 'N15', 'N4']
#  +++ old travel cost: [552350.0]
#  +++ new travel cost: [314000.0]
#  +++ END re-optimize PDOTW solution for  truck [T5]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T21]
#  +++ Truck [T21]: [['N11', 'N7', 'N27', 'N15', 'N16', 'N21', 'N29']]
#  +++ Cargos to deliver: [['C27', 'C53', 'C136', 'C179', 'C181', 'C189', 'C196', 'C226', 'C248']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case1_gurobi/truckT21_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 22900
#    [Gurobi runtime] is 0.000922
#  +++ New route ['N11', 'N7', 'N27', 'N21', 'N15', 'N29']
#  +++ old travel cost: [552350.0]
#  +++ new travel cost: [336900.0]
#  +++ END re-optimize PDOTW solution for  truck [T21]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T7]
#  +++ Truck [T7]: [['N5', 'N10', 'N33', 'N31', 'N25', 'N19', 'N6', 'N24', 'N27']]
#  +++ Cargos to deliver: [['C14', 'C34', 'C41', 'C73', 'C107', 'C119']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case1_gurobi/truckT7_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 22950
#    [Gurobi runtime] is 0.008587
#  +++ New route ['N5', 'N10', 'N6', 'N24', 'N33', 'N31', 'N25', 'N19', 'N27']
#  +++ old travel cost: [552350.0]
#  +++ new travel cost: [359850.0]
#  +++ END re-optimize PDOTW solution for  truck [T7]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T16]
#  +++ Truck [T16]: [['N11', 'N7', 'N14', 'N2', 'N32', 'N23', 'N17']]
#  +++ Cargos to deliver: [['C26', 'C100', 'C129', 'C183', 'C254']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case1_gurobi/truckT16_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 25350
#    [Gurobi runtime] is 0.000579
#  +++ New route ['N11', 'N7', 'N14', 'N2', 'N23', 'N17']
#  +++ old travel cost: [552350.0]
#  +++ new travel cost: [385200.0]
#  +++ END re-optimize PDOTW solution for  truck [T16]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T17]
#  +++ Truck [T17]: [['N11', 'N5', 'N10', 'N17', 'N14', 'N16']]
#  +++ Cargos to deliver: [['C13', 'C75', 'C110', 'C153', 'C155']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case1_gurobi/truckT17_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 27300
#    [Gurobi runtime] is 0.000936
#  +++ New route ['N11', 'N5', 'N10', 'N17', 'N14', 'N16']
#  +++ old travel cost: [552350.0]
#  +++ new travel cost: [412500.0]
#  +++ END re-optimize PDOTW solution for  truck [T17]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T9]
#  +++ Truck [T9]: [['N5', 'N10', 'N21', 'N15', 'N4', 'N9', 'N3', 'N23']]
#  +++ Cargos to deliver: [['C17', 'C44', 'C89', 'C177']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case1_gurobi/truckT9_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 32100
#    [Gurobi runtime] is 0.000786
#  +++ New route ['N5', 'N10', 'N21', 'N15', 'N4', 'N9', 'N3', 'N23']
#  +++ old travel cost: [552350.0]
#  +++ new travel cost: [444600.0]
#  +++ END re-optimize PDOTW solution for  truck [T9]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T2]
#  +++ Truck [T2]: [['N7', 'N5', 'N19', 'N32', 'N30', 'N13']]
#  +++ Cargos to deliver: [['C4', 'C125', 'C178', 'C253']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case1_gurobi/truckT2_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 33450
#    [Gurobi runtime] is 0.000858
#  +++ New route ['N7', 'N5', 'N19', 'N32', 'N30', 'N13']
#  +++ old travel cost: [552350.0]
#  +++ new travel cost: [478050.0]
#  +++ END re-optimize PDOTW solution for  truck [T2]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T14]
#  +++ Truck [T14]: [['N11', 'N10', 'N30', 'N22']]
#  +++ Cargos to deliver: [['C45']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case1_gurobi/truckT14_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 33550
#    [Gurobi runtime] is 0.000244
#  +++ New route ['N11', 'N10', 'N30', 'N22']
#  +++ old travel cost: [552350.0]
#  +++ new travel cost: [511600.0]
#  +++ END re-optimize PDOTW solution for  truck [T14]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T13]
#  +++ Truck [T13]: [['N10', 'N21', 'N17']]
#  +++ Cargos to deliver: [['C228']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/
reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 27300
#    [Gurobi runtime] is 0.002137
#  +++ New route ['N21', 'N27', 'N10', 'N6', 'N23', 'N15', 'N8']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [114450.0]
#  +++ END re-optimize PDOTW solution for  truck [T2]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T10]
#  +++ Truck [T10]: [['N24', 'N1', 'N8', 'N25', 'N18']]
#  +++ Cargos to deliver: [['C16', 'C48', 'C50', 'C51', 'C52', 'C53', 'C60', 'C81', 'C82', 'C83', 'C88', 'C100', 'C108', 'C114', 'C115', 'C117', 'C128', 'C132', 'C133']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT10_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 31950
#    [Gurobi runtime] is 0.000455
#  +++ New route ['N24', 'N1', 'N8', 'N25', 'N18']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [146400.0]
#  +++ END re-optimize PDOTW solution for  truck [T10]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T3]
#  +++ Truck [T3]: [['N21', 'N24', 'N26', 'N17', 'N14', 'N3']]
#  +++ Cargos to deliver: [['C2', 'C35', 'C39', 'C56']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT3_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 27850
#    [Gurobi runtime] is 0.001130
#  +++ New route ['N21', 'N24', 'N26', 'N17', 'N14', 'N3']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [174250.0]
#  +++ END re-optimize PDOTW solution for  truck [T3]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T4]
#  +++ Truck [T4]: [['N21', 'N22', 'N13', 'N4', 'N9']]
#  +++ Cargos to deliver: [['C21', 'C22', 'C23', 'C24', 'C66', 'C70', 'C116']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT4_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 32300
#    [Gurobi runtime] is 0.000520
#  +++ New route ['N21', 'N22', 'N13', 'N4', 'N9']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [206550.0]
#  +++ END re-optimize PDOTW solution for  truck [T4]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T12]
#  +++ Truck [T12]: [['N24', 'N21', 'N2', 'N19', 'N3', 'N9']]
#  +++ Cargos to deliver: [['C15', 'C18', 'C59', 'C65', 'C84', 'C102']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT12_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 28400
#    [Gurobi runtime] is 0.000753
#  +++ New route ['N24', 'N21', 'N2', 'N19', 'N3', 'N9']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [234950.0]
#  +++ END re-optimize PDOTW solution for  truck [T12]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T14]
#  +++ Truck [T14]: [['N24', 'N14', 'N16', 'N7', 'N23']]
#  +++ Cargos to deliver: [['C61', 'C62', 'C87', 'C92', 'C109']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT14_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 34650
#    [Gurobi runtime] is 0.000782
#  +++ New route ['N24', 'N14', 'N16', 'N7', 'N23']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [269600.0]
#  +++ END re-optimize PDOTW solution for  truck [T14]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T8]
#  +++ Truck [T8]: [['N21', 'N1', 'N9', 'N11', 'N5', 'N7']]
#  +++ Cargos to deliver: [['C12', 'C26', 'C30', 'C33', 'C36']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT8_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 30500
#    [Gurobi runtime] is 0.001467
#  +++ New route ['N21', 'N1', 'N9', 'N11', 'N5', 'N7']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [300100.0]
#  +++ END re-optimize PDOTW solution for  truck [T8]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T9]
#  +++ Truck [T9]: [['N21', 'N8', 'N25', 'N1']]
#  +++ Cargos to deliver: [['C11', 'C37', 'C71', 'C77']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT9_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 33700
#    [Gurobi runtime] is 0.000421
#  +++ New route ['N21', 'N8', 'N25', 'N1']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [333800.0]
#  +++ END re-optimize PDOTW solution for  truck [T9]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T5]
#  +++ Truck [T5]: [['N21', 'N20', 'N18', 'N16', 'N19']]
#  +++ Cargos to deliver: [['C5', 'C10', 'C29']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT5_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 33000
#    [Gurobi runtime] is 0.000600
#  +++ New route ['N21', 'N20', 'N18', 'N16', 'N19']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [366800.0]
#  +++ END re-optimize PDOTW solution for  truck [T5]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T1]
#  +++ Truck [T1]: [['N21', 'N24', 'N23', 'N14', 'N3', 'N6']]
#  +++ Cargos to deliver: [['C20', 'C105']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT1_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 29100
#    [Gurobi runtime] is 0.000464
#  +++ New route ['N21', 'N24', 'N23', 'N3', 'N6']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [395900.0]
#  +++ END re-optimize PDOTW solution for  truck [T1]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T7]
#  +++ Truck [T7]: [['N21', 'N24', 'N7', 'N4']]
#  +++ Cargos to deliver: [['C47', 'C118']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT7_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 29850
#    [Gurobi runtime] is 0.000296
#  +++ New route ['N21', 'N24', 'N7', 'N4']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [425750.0]
#  +++ END re-optimize PDOTW solution for  truck [T7]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T16]
#  +++ Truck [T16]: [['N24', 'N14', 'N25']]
#  +++ Cargos to deliver: [['C3']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case3_gurobi/truckT16_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 27450
#    [Gurobi runtime] is 0.000198
#  +++ New route ['N24', 'N14', 'N25']
#  +++ old travel cost: [456750.0]
#  +++ new travel cost: [453200.0]
#  +++ END re-optimize PDOTW solution for  truck [T16]
#
# ====== Re-optimize PDOTW solutions for Case 4
# ========= Reoptimize the route of PDOTW sol on Truck [T10]
#  +++ Truck [T10]: [['N6', 'N9', 'N11']]
#  +++ Cargos to deliver: [['C7', 'C10', 'C38', 'C39', 'C40', 'C52', 'C81', 'C82', 'C97', 'C99', 'C105', 'C120', 'C121', 'C122', 'C125', 'C129', 'C130', 'C133', 'C142', 'C150', 'C151', 'C166']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT10_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 10450
#    [Gurobi runtime] is 0.000259
#  +++ New route ['N6', 'N9', 'N11']
#  +++ old travel cost: [387750.0]
#  +++ new travel cost: [10450.0]
#  +++ END re-optimize PDOTW solution for  truck [T10]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T12]
#  +++ Truck [T12]: [['N6', 'N25', 'N2', 'N13', 'N4', 'N34', 'N11', 'N6']]
#  +++ Cargos to deliver: [['C13', 'C14', 'C16', 'C30', 'C41', 'C44', 'C54', 'C59', 'C95', 'C108', 'C123', 'C127', 'C132', 'C155', 'C163']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT12_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 20100
#    [Gurobi runtime] is 0.041517
#  +++ New route ['N6', 'N2', 'N25', 'N34', 'N4', 'N13', 'N11', 'N6']
#  +++ old travel cost: [387750.0]
#  +++ new travel cost: [30550.0]
#  +++ END re-optimize PDOTW solution for  truck [T12]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T15]
#  +++ Truck [T15]: [['N6', 'N37', 'N16', 'N44', 'N43', 'N19', 'N32']]
#  +++ Cargos to deliver: [['C6', 'C8', 'C37', 'C65', 'C69', 'C80', 'C90', 'C112', 'C119', 'C124', 'C136', 'C137', 'C138', 'C144', 'C164']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT15_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 24650
#    [Gurobi runtime] is 0.001700
#  +++ New route ['N6', 'N16', 'N37', 'N44', 'N43', 'N19', 'N32']
#  +++ old travel cost: [387750.0]
#  +++ new travel cost: [55200.0]
#  +++ END re-optimize PDOTW solution for  truck [T15]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T19]
#  +++ Truck [T19]: [['N6', 'N34', 'N25', 'N37', 'N9', 'N6']]
#  +++ Cargos to deliver: [['C9', 'C42', 'C48', 'C49', 'C50', 'C66', 'C68', 'C101', 'C110', 'C139', 'C157']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT19_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 
]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT18_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 30350
#    [Gurobi runtime] is 0.002723
#  +++ New route ['N6', 'N50', 'N28', 'N20', 'N30', 'N40', 'N43']
#  +++ old travel cost: [387750.0]
#  +++ new travel cost: [256300.0]
#  +++ END re-optimize PDOTW solution for  truck [T18]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T5]
#  +++ Truck [T5]: [['N6', 'N2', 'N35', 'N11', 'N15', 'N6']]
#  +++ Cargos to deliver: [['C3', 'C20', 'C23', 'C33', 'C161']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT5_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 30100
#    [Gurobi runtime] is 0.000981
#  +++ New route ['N6', 'N15', 'N35', 'N11', 'N2', 'N6']
#  +++ old travel cost: [387750.0]
#  +++ new travel cost: [286400.0]
#  +++ END re-optimize PDOTW solution for  truck [T5]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T7]
#  +++ Truck [T7]: [['N6', 'N31', 'N23', 'N29', 'N1', 'N14', 'N36', 'N48']]
#  +++ Cargos to deliver: [['C18', 'C22', 'C26', 'C28', 'C76', 'C88']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT7_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 19950
#    [Gurobi runtime] is 0.002413
#  +++ New route ['N6', 'N31', 'N1', 'N23', 'N29', 'N36', 'N48']
#  +++ old travel cost: [387750.0]
#  +++ new travel cost: [306350.0]
#  +++ END re-optimize PDOTW solution for  truck [T7]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T8]
#  +++ Truck [T8]: [['N6', 'N13', 'N26', 'N14', 'N46', 'N4', 'N45', 'N21', 'N39']]
#  +++ Cargos to deliver: [['C43', 'C57', 'C93', 'C96', 'C104', 'C116']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT8_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 30650
#    [Gurobi runtime] is 0.052066
#  +++ New route ['N6', 'N13', 'N4', 'N46', 'N14', 'N26', 'N45', 'N21', 'N39']
#  +++ old travel cost: [387750.0]
#  +++ new travel cost: [337000.0]
#  +++ END re-optimize PDOTW solution for  truck [T8]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T16]
#  +++ Truck [T16]: [['N6', 'N19', 'N50', 'N45']]
#  +++ Cargos to deliver: [['C21', 'C31']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case4_gurobi/truckT16_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 24100
#    [Gurobi runtime] is 0.001264
#  +++ New route ['N6', 'N19', 'N50', 'N45']
#  +++ old travel cost: [387750.0]
#  +++ new travel cost: [361100.0]
#  +++ END re-optimize PDOTW solution for  truck [T16]
#
# ====== Re-optimize PDOTW solutions for Case 5
# ========= Reoptimize the route of PDOTW sol on Truck [T11]
#  +++ Truck [T11]: [['N5', 'N23', 'N36', 'N38', 'N50', 'N33']]
#  +++ Cargos to deliver: [['C15', 'C24', 'C40', 'C57', 'C58', 'C60', 'C65', 'C66']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT11_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 26600
#    [Gurobi runtime] is 0.006534
#  +++ New route ['N5', 'N50', 'N38', 'N23', 'N36', 'N33']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [26600.0]
#  +++ END re-optimize PDOTW solution for  truck [T11]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T20]
#  +++ Truck [T20]: [['N5', 'N21', 'N35', 'N24', 'N47', 'N49']]
#  +++ Cargos to deliver: [['C13', 'C36', 'C44', 'C45', 'C53', 'C56', 'C61', 'C62']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT20_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 30250
#    [Gurobi runtime] is 0.000773
#  +++ New route ['N5', 'N21', 'N35', 'N24', 'N47', 'N49']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [56850.0]
#  +++ END re-optimize PDOTW solution for  truck [T20]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T18]
#  +++ Truck [T18]: [['N5', 'N25', 'N32', 'N31', 'N10', 'N27', 'N12']]
#  +++ Cargos to deliver: [['C2', 'C4', 'C29', 'C31', 'C54', 'C64', 'C68']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT18_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 26350
#    [Gurobi runtime] is 0.002656
#  +++ New route ['N5', 'N10', 'N25', 'N27', 'N31', 'N32', 'N12']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [83200.0]
#  +++ END re-optimize PDOTW solution for  truck [T18]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T15]
#  +++ Truck [T15]: [['N5', 'N41', 'N16', 'N17', 'N30', 'N18', 'N3']]
#  +++ Cargos to deliver: [['C1', 'C8', 'C20', 'C22', 'C49', 'C55', 'C67']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT15_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 30050
#    [Gurobi runtime] is 0.004482
#  +++ New route ['N5', 'N41', 'N16', 'N17', 'N30', 'N18', 'N3']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [113250.0]
#  +++ END re-optimize PDOTW solution for  truck [T15]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T1]
#  +++ Truck [T1]: [['N5', 'N39', 'N45', 'N6', 'N19', 'N27']]
#  +++ Cargos to deliver: [['C11', 'C28', 'C30', 'C48']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT1_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 25300
#    [Gurobi runtime] is 0.001112
#  +++ New route ['N5', 'N39', 'N19', 'N45', 'N27']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [138550.0]
#  +++ END re-optimize PDOTW solution for  truck [T1]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T19]
#  +++ Truck [T19]: [['N5', 'N20', 'N50', 'N4', 'N12', 'N41']]
#  +++ Cargos to deliver: [['C23', 'C37', 'C41', 'C46']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT19_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 29150
#    [Gurobi runtime] is 0.001952
#  +++ New route ['N5', 'N20', 'N4', 'N50', 'N12', 'N41']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [167700.0]
#  +++ END re-optimize PDOTW solution for  truck [T19]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T12]
#  +++ Truck [T12]: [['N5', 'N37', 'N40', 'N26', 'N23']]
#  +++ Cargos to deliver: [['C3', 'C25', 'C43']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT12_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 28450
#    [Gurobi runtime] is 0.001560
#  +++ New route ['N5', 'N40', 'N26', 'N37', 'N23']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [196150.0]
#  +++ END re-optimize PDOTW solution for  truck [T12]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T3]
#  +++ Truck [T3]: [['N5', 'N44', 'N16', 'N13', 'N42', 'N28']]
#  +++ Cargos to deliver: [['C7', 'C21', 'C50', 'C59']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT3_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 29700
#    [Gurobi runtime] is 0.001254
#  +++ New route ['N5', 'N44', 'N16', 'N13', 'N42', 'N28']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [225850.0]
#  +++ END re-optimize PDOTW solution for  truck [T3]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T4]
#  +++ Truck [T4]: [['N5', 'N22', 'N33', 'N46', 'N40']]
#  +++ Cargos to deliver: [['C6', 'C47', 'C63']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT4_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 30600
#    [Gurobi runtime] is 0.000779
#  +++ New route ['N5', 'N22', 'N33', 'N46', 'N40']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [256450.0]
#  +++ END re-optimize PDOTW solution for  truck [T4]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T10]
#  +++ Truck [T10]: [['N5', 'N8', 'N1', 'N32', 'N15']]
#  +++ Cargos to deliver: [['C18', 'C27', 'C33']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT10_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 26650
#    [Gurobi runtime] is 0.001559
#  +++ New route ['N5', 'N8', 'N32', 'N1', 'N15']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [283100.0]
#  +++ END re-optimize PDOTW solution for  truck [T10]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T6]
#  +++ Truck [T6]: [['N5', 'N41', 'N33', 'N7', 'N14']]
#  +++ Cargos to deliver: [['C17', 'C42', 'C51']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT6_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 30300
#    [Gurobi runtime] is 0.000580
#  +++ New route ['N5', 'N41', 'N33', 'N7', 'N14']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [313400.0]
#  +++ END re-optimize PDOTW solution for  truck [T6]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T8]
#  +++ Truck [T8]: [['N5', 'N23', 'N2', 'N6', 'N11']]
#  +++ Cargos to deliver: [['C10', 'C16']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT8_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 20700
#    [Gurobi runtime] is 0.000608
#  +++ New route ['N5', 'N2', 'N6', 'N11']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [334100.0]
#  +++ END re-optimize PDOTW solution for  truck [T8]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T5]
#  +++ Truck [T5]: [['N5', 'N14', 'N28', 'N9', 'N3', 'N29', 'N23']]
#  +++ Cargos to deliver: [['C9']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT5_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 17450
#    [Gurobi runtime] is 0.000233
#  +++ New route ['N5', 'N14', 'N23']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [351550.0]
#  +++ END re-optimize PDOTW solution for  truck [T5]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T21]
#  +++ Truck [T21]: [['N5', 'N15', 'N20']]
#  +++ Cargos to deliver: [['C14']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT21_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 24700
#    [Gurobi runtime] is 0.000199
#  +++ New route ['N5', 'N15', 'N20']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [376250.0]
#  +++ END re-optimize PDOTW solution for  truck [T21]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T7]
#  +++ Truck [T7]: [['N5', 'N9', 'N48']]
#  +++ Cargos to deliver: [['C5']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT7_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 17550
#    [Gurobi runtime] is 0.000184
#  +++ New route ['N5', 'N9', 'N48']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [393800.0]
#  +++ END re-optimize PDOTW solution for  truck [T7]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T16]
#  +++ Truck [T16]: [['N5', 'N43', 'N34', 'N11', 'N22']]
#  +++ Cargos to deliver: [['C12', 'C34']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT16_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 28350
#    [Gurobi runtime] is 0.000539
#  +++ New route ['N5', 'N43', 'N11', 'N22']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [422150.0]
#  +++ END re-optimize PDOTW solution for  truck [T16]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T17]
#  +++ Truck [T17]: [['N5', 'N3', 'N29', 'N23', 'N24']]
#  +++ Cargos to deliver: [['C35', 'C52']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT17_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 25050
#    [Gurobi runtime] is 0.000451
#  +++ New route ['N5', 'N3', 'N29', 'N24']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [447200.0]
#  +++ END re-optimize PDOTW solution for  truck [T17]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T9]
#  +++ Truck [T9]: [['N5', 'N23', 'N28', 'N48', 'N51', 'N9']]
#  +++ Cargos to deliver: [['C26', 'C38']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT9_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 17900
#    [Gurobi runtime] is 0.000438
#  +++ New route ['N5', 'N51', 'N48', 'N9']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [465100.0]
#  +++ END re-optimize PDOTW solution for  truck [T9]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T2]
#  +++ Truck [T2]: [['N5', 'N28', 'N23', 'N50']]
#  +++ Cargos to deliver: [['C19']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT2_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 17050
#    [Gurobi runtime] is 0.000317
#  +++ New route ['N5', 'N28', 'N50']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [482150.0]
#  +++ END re-optimize PDOTW solution for  truck [T2]
#
# ========= Reoptimize the route of PDOTW sol on Truck [T14]
#  +++ Truck [T14]: [['N5', 'N23', 'N34', 'N29']]
#  +++ Cargos to deliver: [['C32', 'C39']]
# Set parameter TimeLimit to value 100
# Set parameter LogFile to value "/home/tan/Documents/GitHub/pdpt_2022/out/case5_gurobi/truckT14_reoptimized.log"
# +++ MP [Feasible]
#    [Gurobi obj value] is 20650
#    [Gurobi runtime] is 0.000747
#  +++ New route ['N5', 'N23', 'N34', 'N29']
#  +++ old travel cost: [544400.0]
#  +++ new travel cost: [502800.0]
#  +++ END re-optimize PDOTW solution for  truck [T14]
